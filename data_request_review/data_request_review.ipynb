# %%
# %%capture
try:
    import pandas, xnat
except ImportError:
    # %pip install -q pandas xnat

# %%
import asyncio
from IPython.display import display, HTML as RawHTML
from ipywidgets import HTML, HBox, VBox, Layout

# CSS for Voila dashboard
display(RawHTML('''
<style>
.header-sort-button button,
.header-sort-button .widget-button,
.header-sort-button .jupyter-button,
.widget-button,
button.jupyter-button,
.lm-Widget button,
.jp-Button button {
    color: #fff !important;
}
.header-sort-button * {
    color: #fff !important;
}
.no-gap {
    gap: 0 !important;
}
.no-gap > * {
    margin: 0 !important;
}
table td, table th {
    text-align: center !important;
}
</style>
'''))

# Landing page skeleton — displayed immediately
header = HTML('<h1 style="margin: 0 0 20px 5px; color: #333; font-size: 32px; font-weight: 600;">Data Request Review</h1>')
status_html = HTML('<span style="color: #856404;">Connecting to XNAT...</span>')

patient_cards_box = HBox([], layout=Layout(flex_flow='row wrap'))
study_cards_box = HBox([], layout=Layout(flex_flow='row wrap'))
charts_box = VBox([])
series_banner_box = VBox([])
missing_patients_box = VBox([])
additional_studies_box = VBox([])
errors_missing_box = VBox([])
missing_series_box = VBox([])

display(VBox([
    header,
    status_html,
    patient_cards_box,
    study_cards_box,
    charts_box,
    series_banner_box,
    missing_patients_box,
    additional_studies_box,
    errors_missing_box,
    missing_series_box,
], layout=Layout(padding='10px')))

# %%
from dashboard import orchestrate

# %%
_ = asyncio.ensure_future(orchestrate(
    status_html,
    patient_cards_box,
    study_cards_box,
    charts_box,
    series_banner_box,
    missing_patients_box,
    additional_studies_box,
    errors_missing_box,
    missing_series_box,
))
